# %% [markdown]
# ### Question 1

# %%
# !pip install pipenv
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Admin-IT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Admin-IT\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Admin-IT\anaconda3\Lib\site-packages)

# %%
# !pipenv --version
# Out:
# pipenv, version 2024.3.0

# %% [markdown]
# ### Question 2

# %%
# !pipenv install scikit-learn==1.5.2
# Out:
# [    ] Creating virtual environment...
# Creating a virtualenv for this project
# Pipfile:
# C:\Users\Admin-IT\Documents\audry\DSweekly\ML_DataTalks_2024\Deployment_05\home
# work_deployment\Pipfile
# Using default python from C:\Users\Admin-IT\anaconda3\python.exe3.11.7 to
# create virtualenv...
# created virtual environment CPython3.11.7.final.0-64 in 2743ms
#   creator
# CPython3Windows(dest=C:\Users\Admin-IT\.virtualenvs\homework_deployment-PcZDFFc
# P, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle,
# wheel=bundle, via=copy,
# app_data_dir=C:\Users\Admin-IT\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==24.3.1, setuptools==75.2.0, wheel==0.44.0
#   activators
# BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator
# ,PythonActivator
#
# Successfully created virtual environment!
# Virtualenv location: C:\Users\Admin-IT\.virtualenvs\homework_deployment-PcZDFFcP
# ...
